# %% [markdown]
# Testing the API

# %%
#| label: import
from urllib.request import urlopen
import pandas as pd
import json
from datetime import datetime

# %% [markdown]
# # Sessions
#
# It looks like each Grand Prix has a 5 associated sessions: Practice 1-3, Qualifying, and then the Race
#
# meeting_key and the meeting query will give you all the races associated with that race weekend.
#
# session_key, meeting_key, and driver_number are going to be the most important for looking across responses

# %%
response = urlopen('https://api.openf1.org/v1/sessions?year=2024')
data = json.loads(response.read().decode('utf-8'))
df = pd.json_normalize(data)
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 response = urlopen('https://api.openf1.org/v1/sessions?year=2024')
#       2 data = json.loads(response.read().decode('utf-8'))
#       3 df = pd.json_normalize(data)
#
# File /opt/anaconda3/lib/python3.12/urllib/request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213 else:
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# File /opt/anaconda3/lib/python3.12/urllib/request.py:521, in OpenerDirector.open(self, fullurl, data, timeout)
#     519 for processor in self.process_response.get(protocol, []):
#     520     meth = getattr(processor, meth_name)
# --> 521     response = meth(req, response)
#     523 return response
#
# File /opt/anaconda3/lib/python3.12/urllib/request.py:630, in HTTPErrorProcessor.http_response(self, request, response)
#     627 # According to RFC 2616, "2xx" code indicates that the client's
#     628 # request was successfully received, understood, and accepted.
#     629 if not (200 <= code < 300):
# --> 630     response = self.parent.error(
#     631         'http', request, response, code, msg, hdrs)
#     633 return response
#
# File /opt/anaconda3/lib/python3.12/urllib/request.py:559, in OpenerDirector.error(self, proto, *args)
#     557 if http_err:
#     558     args = (dict, 'default', 'http_error_default') + orig_args
# --> 559     return self._call_chain(*args)
#
# File /opt/anaconda3/lib/python3.12/urllib/request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     490 for handler in handlers:
#     491     func = getattr(handler, meth_name)
# --> 492     result = func(*args)
#     493     if result is not None:
#     494         return result
#
# File /opt/anaconda3/lib/python3.12/urllib/request.py:639, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     638 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 639     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 500: Internal Server Error

# %%
format_string = "%Y-%m-%d %H:%M:%S"
df['date_end'] = pd.to_datetime(df['date_end'])
df['date_start'] = pd.to_datetime(df['date_start'])
df['duration'] = df['date_end'] - df['date_start']
df.head(10)
# Out:
#    session_key session_name                date_start  \
# 0         9465   Practice 1 2024-02-29 11:30:00+00:00
# 1         9466   Practice 2 2024-02-29 15:00:00+00:00
# 2         9467   Practice 3 2024-03-01 12:30:00+00:00
# 3         9468   Qualifying 2024-03-01 16:00:00+00:00
# 4         9472         Race 2024-03-02 15:00:00+00:00
# 5         9473   Practice 1 2024-03-07 13:30:00+00:00
# 6         9474   Practice 2 2024-03-07 17:00:00+00:00
# 7         9475   Practice 3 2024-03-08 13:30:00+00:00
# 8         9476   Qualifying 2024-03-08 17:00:00+00:00
# 9         9480         Race 2024-03-09 17:00:00+00:00
#
#                    date_end gmt_offset session_type  meeting_key location  \
# 0 2024-02-29 12:30:00+00:00   03:00:00     Practice         1229   Sakhir
# 1 2024-02-29 16:00:00+00:00   03:00:00     Practice         1229   Sakhir
# 2 2024-03-01 13:30:00+00:00   03:00:00     Practice         1229   Sakhir
# 3 2024-03-01 17:00:00+00:00   03:00:00   Qualifying         1229   Sakhir
# 4 2024-03-02 17:00:00+00:00   03:00:00         Race         1229   Sakhir
# 5 2024-03-07 14:30:00+00:00   03:00:00     Practice         1230   Jeddah
# 6 2024-03-07 18:00:00+00:00   03:00:00     Practice         1230   Jeddah
# 7 2024-03-08 14:30:00+00:00   03:00:00     Practice         1230   Jeddah
# 8 2024-03-08 18:00:00+00:00   03:00:00   Qualifying         1230   Jeddah
# 9 2024-03-09 19:00:00+00:00   03:00:00         Race         1230   Jeddah
#
#    country_key country_code  country_name  circuit_key circuit_short_name  \
# 0           36          BRN       Bahrain           63             Sakhir
# 1           36          BRN       Bahrain           63             Sakhir
# 2           36          BRN       Bahrain           63             Sakhir
# 3           36          BRN       Bahrain           63             Sakhir
# 4           36          BRN       Bahrain           63             Sakhir
# 5          153          KSA  Saudi Arabia          149             Jeddah
# 6          153          KSA  Saudi Arabia          149             Jeddah
# 7          153          KSA  Saudi Arabia          149             Jeddah
# 8          153          KSA  Saudi Arabia          149             Jeddah
# 9          153          KSA  Saudi Arabia          149             Jeddah
#
#    year        duration
# 0  2024 0 days 01:00:00
# 1  2024 0 days 01:00:00
# 2  2024 0 days 01:00:00
# 3  2024 0 days 01:00:00
# 4  2024 0 days 02:00:00
# 5  2024 0 days 01:00:00
# 6  2024 0 days 01:00:00
# 7  2024 0 days 01:00:00
# 8  2024 0 days 01:00:00
# 9  2024 0 days 02:00:00

# %% [markdown]
# The session numbers are chronological for the practice and qualifying, but not for the actual Race.
#
# # Drivers
# Looking at the drivers for a specific session (2024 Bahrain Grand Prix)

# %%
response = urlopen('https://api.openf1.org/v1/drivers?session_key=9472')
data = json.loads(response.read().decode('utf-8'))
df = pd.json_normalize(data)
df.head(10)
# Out:
#    session_key  meeting_key broadcast_name country_code first_name  \
# 0         9472         1229   M VERSTAPPEN          NED        Max
# 1         9472         1229     L SARGEANT          USA      Logan
# 2         9472         1229    D RICCIARDO          AUS     Daniel
# 3         9472         1229       L NORRIS          GBR      Lando
# 4         9472         1229        P GASLY          FRA     Pierre
# 5         9472         1229        S PEREZ          MEX     Sergio
# 6         9472         1229       F ALONSO          ESP   Fernando
# 7         9472         1229      C LECLERC          MON    Charles
# 8         9472         1229       L STROLL          CAN      Lance
# 9         9472         1229    K MAGNUSSEN          DEN      Kevin
#
#           full_name                                       headshot_url  \
# 0    Max VERSTAPPEN  https://media.formula1.com/d_driver_fallback_i...
# 1    Logan SARGEANT  https://media.formula1.com/d_driver_fallback_i...
# 2  Daniel RICCIARDO  https://media.formula1.com/d_driver_fallback_i...
# 3      Lando NORRIS  https://media.formula1.com/d_driver_fallback_i...
# 4      Pierre GASLY  https://media.formula1.com/d_driver_fallback_i...
# 5      Sergio PEREZ  https://media.formula1.com/d_driver_fallback_i...
# 6   Fernando ALONSO  https://media.formula1.com/d_driver_fallback_i...
# 7   Charles LECLERC  https://media.formula1.com/d_driver_fallback_i...
# 8      Lance STROLL  https://media.formula1.com/d_driver_fallback_i...
# 9   Kevin MAGNUSSEN  https://media.formula1.com/d_driver_fallback_i...
#
#     last_name  driver_number team_colour        team_name name_acronym
# 0  Verstappen              1      3671C6  Red Bull Racing          VER
# 1    Sargeant              2      64C4FF         Williams          SAR
# 2   Ricciardo              3      6692FF               RB          RIC
# 3      Norris              4      FF8000          McLaren          NOR
# 4       Gasly             10      FF87BC           Alpine          GAS
# 5       Perez             11      3671C6  Red Bull Racing          PER
# 6      Alonso             14      229971     Aston Martin          ALO
# 7     Leclerc             16      E8002D          Ferrari          LEC
# 8      Stroll             18      229971     Aston Martin          STR
# 9   Magnussen             20      B6BABD     Haas F1 Team          MAG

# %% [markdown]
# # Practice Round Info
#
# Looking at what sort of information we can get from practice rounds
#
# ## Stints

# %%
response = urlopen('https://api.openf1.org/v1/stints?driver_number=16&session_key=9467')
data = json.loads(response.read().decode('utf-8'))
df = pd.json_normalize(data)
df.head(10)
# Out:
#    meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 0         1229         9467             1             16          1        4
# 1         1229         9467             2             16          5        7
# 2         1229         9467             3             16          8       12
# 3         1229         9467             4             16         13       18
#
#   compound  tyre_age_at_start
# 0     SOFT                  0
# 1     SOFT                  3
# 2     SOFT                  6
# 3     SOFT                  0

# %% [markdown]
# Stints gives us how long they used a set of tires.
#
# ## Laps

# %%
response = urlopen('https://api.openf1.org/v1/laps?driver_number=16&session_key=9467')
data = json.loads(response.read().decode('utf-8'))
df = pd.json_normalize(data)
print(len(df))
df.tail(10)
# Out:
# 17
#     meeting_key  session_key  driver_number  i1_speed  i2_speed  st_speed  \
# 7          1229         9467             16       239       268       308
# 8          1229         9467             16       163       132       177
# 9          1229         9467             16       208       231       306
# 10         1229         9467             16       238       268       308
# 11         1229         9467             16       180       185       120
# 12         1229         9467             16       240       271       313
# 13         1229         9467             16       147       135       228
# 14         1229         9467             16       240       272       315
# 15         1229         9467             16       164       171       242
# 16         1229         9467             16       211       206       269
#
#                           date_start  lap_duration  is_pit_out_lap  \
# 7   2024-03-01T13:07:44.784000+00:00        92.693           False
# 8   2024-03-01T13:09:17.388000+00:00       146.232           False
# 9   2024-03-01T13:11:43.604000+00:00       100.083           False
# 10  2024-03-01T13:13:23.710000+00:00        95.286           False
# 11  2024-03-01T13:23:36.999000+00:00       638.916            True
# 12  2024-03-01T13:25:37.962000+00:00        91.094           False
# 13  2024-03-01T13:27:08.962000+00:00       144.202           False
# 14  2024-03-01T13:29:33.252000+00:00        91.337           False
# 15  2024-03-01T13:31:04.598000+00:00       131.299           False
# 16  2024-03-01T13:33:16.112000+00:00       134.944           False
#
#     duration_sector_1  duration_sector_2  duration_sector_3  \
# 7              29.782             39.886             23.025
# 8              46.550             66.994             32.688
# 9              33.384             43.014             23.685
# 10             29.686             40.139             25.461
# 11            558.401             53.524             26.991
# 12             29.437             38.930             22.727
# 13             50.170             60.172             33.860
# 14             29.447             39.105             22.785
# 15             39.057             53.779             38.463
# 16             62.726             44.944             27.274
#
#                                     segments_sector_1  \
# 7   [2048, 2048, 2048, 2049, 2048, 2048, 2048, 204...
# 8   [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 9   [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 10  [None, 2048, 2048, 2048, 2049, 2049, 2048, 204...
# 11  [2064, 2064, 2064, 2048, 2048, 2048, 2048, 204...
# 12  [2049, 2049, 2049, 2051, 2049, 2049, 2048, 204...
# 13  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 14  [2049, 2049, 2049, 2048, 2048, 2049, 2049, 204...
# 15  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 16  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#
#                                     segments_sector_2  \
# 7   [2048, 2048, 2049, 2048, 2048, 2048, 2048, 204...
# 8   [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 9   [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 10  [2049, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 11  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 12  [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 13  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 14  [2049, 2049, 2048, 2048, 2048, 2048, 2048, 204...
# 15  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 16  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#
#                              segments_sector_3  lap_number
# 7   [2048, 2048, 2048, 2048, 2048, 2048, 2048]           8
# 8   [2048, 2048, 2048, 2048, 2048, 2048, 2048]           9
# 9                        [0, 0, 0, 0, 0, 0, 0]          10
# 10  [2048, 2048, 2048, 2048, 2048, 2048, 2048]          11
# 11     [2049, 2049, 2049, 2048, 2048, 2048, 0]          12
# 12  [2048, 2048, 2048, 2048, 2048, 2049, 2048]          13
# 13  [2048, 2048, 2048, 2048, 2048, 2049, 2048]          14
# 14  [2048, 2048, 2048, 2048, 2048, 2048, 2048]          15
# 15  [2048, 2048, 2048, 2048, 2048, 2048, 2064]          16
# 16                                          []          17

# %%
# minimum lap duration 
print(df['lap_duration'].min())
# Out:
# 91.094

# %% [markdown]
# ## Qualifying
#
# Now looking at the minimum lap_duration and number of stints for the qualifying round.

# %%
response = urlopen('https://api.openf1.org/v1/stints?driver_number=16&session_key=9468')
data = json.loads(response.read().decode('utf-8'))
df = pd.json_normalize(data)
df.head(10)
# Out:
#    meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 0         1229         9468             1             16          1        4
# 1         1229         9468             2             16          5        8
# 2         1229         9468             3             16          8        9
# 3         1229         9468             4             16          9       12
# 4         1229         9468             5             16         12       15
# 5         1229         9468             6             16         15       16
# 6         1229         9468             7             16         17       20
#
#   compound  tyre_age_at_start
# 0   MEDIUM                  0
# 1     SOFT                  0
# 2     SOFT                  0
# 3     SOFT                  3
# 4     SOFT                  0
# 5     SOFT                  1
# 6     SOFT                  0

# %%
response = urlopen('https://api.openf1.org/v1/laps?driver_number=16&session_key=9468')
data = json.loads(response.read().decode('utf-8'))
df = pd.json_normalize(data)
print("Minimum Lap Duration:")
print(df['lap_duration'].min())
# Out:
# Minimum Lap Duration:
# 89.165

# %% [markdown]
# Now I'll see how that relates to the starting position for the actual race.

# %%
response = urlopen('https://api.openf1.org/v1/laps?session_key=9468')
data = json.loads(response.read().decode('utf-8'))
df = pd.json_normalize(data)

# find all drivers in qualifying round
all_drivers = df['driver_number'].unique()

min_laps_list = []


for d_id in all_drivers:
    sub_df = df[df['driver_number']==d_id]
    min_lap = (sub_df['lap_duration'].min())
    # print(d_id, min_lap)
    min_laps_list.append(["9468",str(d_id), min_lap])

min_laps_df = pd.DataFrame(min_laps_list, columns=['session_key', 'driver_number','min_lap_duration'])
min_laps_df = min_laps_df.sort_values(by='min_lap_duration')
print(min_laps_df)
# Out:
#    session_key driver_number  min_lap_duration
# 1         9468            16            89.165
# 16        9468             1            89.179
# 17        9468            63            89.485
# 0         9468            55            89.507
# 19        9468            11            89.537
# 15        9468            14            89.542
# 14        9468             4            89.614
# 12        9468            81            89.683
# 18        9468            44            89.710
# 6         9468            27            89.851
# 13        9468            18            89.965
# 8         9468            22            90.129
# 4         9468            23            90.221
# 5         9468             3            90.278
# 10        9468            20            90.529
# 11        9468            77            90.756
# 9         9468            24            90.757
# 7         9468             2            90.770
# 2         9468            31            90.793
# 3         9468            10            90.948

# %% [markdown]
# ## Position Query

# %%
response = urlopen('https://api.openf1.org/v1/position?session_key=9472')
data = json.loads(response.read().decode('utf-8'))
df = pd.json_normalize(data)

# 20 drivers starting positions
df = df.iloc[0:19,]
df  = df.sort_values(by='position')
df.head(20)
# Out:
#     session_key  meeting_key  driver_number                              date  \
# 0          9472         1229              1  2024-03-02T14:03:47.739000+00:00
# 7          9472         1229             16  2024-03-02T14:03:47.739000+00:00
# 17         9472         1229             63  2024-03-02T14:03:47.739000+00:00
# 16         9472         1229             55  2024-03-02T14:03:47.739000+00:00
# 5          9472         1229             11  2024-03-02T14:03:47.739000+00:00
# 6          9472         1229             14  2024-03-02T14:03:47.739000+00:00
# 3          9472         1229              4  2024-03-02T14:03:47.739000+00:00
# 15         9472         1229             44  2024-03-02T14:03:47.739000+00:00
# 13         9472         1229             27  2024-03-02T14:03:47.739000+00:00
# 10         9472         1229             22  2024-03-02T14:03:47.739000+00:00
# 8          9472         1229             18  2024-03-02T14:03:47.739000+00:00
# 11         9472         1229             23  2024-03-02T14:03:47.739000+00:00
# 2          9472         1229              3  2024-03-02T14:03:47.739000+00:00
# 9          9472         1229             20  2024-03-02T14:03:47.739000+00:00
# 18         9472         1229             77  2024-03-02T14:03:47.739000+00:00
# 12         9472         1229             24  2024-03-02T14:03:47.739000+00:00
# 1          9472         1229              2  2024-03-02T14:03:47.739000+00:00
# 14         9472         1229             31  2024-03-02T14:03:47.739000+00:00
# 4          9472         1229             10  2024-03-02T14:03:47.739000+00:00
#
#     position
# 0          1
# 7          2
# 17         3
# 16         4
# 5          5
# 6          6
# 3          7
# 15         9
# 13        10
# 10        11
# 8         12
# 11        13
# 2         14
# 9         15
# 18        16
# 12        17
# 1         18
# 14        19
# 4         20

# %% [markdown]
# # Car Data
#
# contains an excessive number of observations for even a single driver in a single session
#
# we will need to do individual queries for the car data, rather than subset

# %%
response = urlopen('https://api.openf1.org/v1/car_data?driver_number=16&session_key=9472')
data = json.loads(response.read().decode('utf-8'))
df = pd.json_normalize(data)
print(len(df))
# Out:
# 34795

# %% [markdown]
# # Pit Duration

# %%
response = urlopen('https://api.openf1.org/v1/pit?driver_number=16&session_key=9468')
data = json.loads(response.read().decode('utf-8'))
df = pd.json_normalize(data)
print(df.head(10))

num_pits = len(df)
avg_pit_time = round(df['pit_duration'].mean(),1)
print(num_pits)
print(avg_pit_time)
# Out:
#    session_key  meeting_key                              date  driver_number  \
# 0         9468         1229  2024-03-01T16:00:16.840000+00:00             16
# 1         9468         1229  2024-03-01T16:07:46.707000+00:00             16
# 2         9468         1229  2024-03-01T16:15:38.681000+00:00             16
# 3         9468         1229  2024-03-01T16:27:49.089000+00:00             16
# 4         9468         1229  2024-03-01T16:36:28.710000+00:00             16
# 5         9468         1229  2024-03-01T16:49:19.625000+00:00             16
# 6         9468         1229  2024-03-01T16:57:29.033000+00:00             16
#
#    pit_duration  lap_number
# 0           NaN           1
# 1         132.4           4
# 2         149.6           7
# 3         604.4           8
# 4         189.9          11
# 5         430.6          14
# 6         175.6          17
# 7
# 280.4
